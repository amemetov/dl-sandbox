# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
# A bit of setup

import numpy as np
import matplotlib.pyplot as plt

from cs231n.classifiers.neural_net import TwoLayerNet

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
  """ returns relative error """
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `cs231n/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
  np.random.seed(0)
  return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
  np.random.seed(1)
  X = 10 * np.random.randn(num_inputs, input_size)
  y = np.array([0, 1, 2, 2, 1])
  return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `cs231n/classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X)
print 'Your scores:'
print scores
print
print 'correct scores:'
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print correct_scores
print

# The difference should be very small. We get < 1e-7
print 'Difference between your scores and correct scores:'
print np.sum(np.abs(scores - correct_scores))
# Out:
# Your scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# 3.68027207459e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularizaion loss.

# %%
loss, _ = net.loss(X, y, reg=0.1)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print 'Difference between your loss and correct loss:'
print np.sum(np.abs(loss - correct_loss))
# Out:
# Difference between your loss and correct loss:
# 1.79856129989e-13

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from cs231n.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.1)

# these should all be less than 1e-8 or so
for param_name in grads:
  f = lambda W: net.loss(X, y, reg=0.1)[0]
  param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
  print '%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name]))
# Out:
# b2 max relative error: 4.447625e-11
# b1 max relative error: 2.738420e-09
# W1 max relative error: 3.561318e-09
# W2 max relative error: 3.440708e-09

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `TwoLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss less than 0.2.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=1e-5,
            num_iters=100, verbose=False)

print 'Final training loss: ', stats['loss_history'][-1]

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Permutation:  [4 3 2 0 1]
# Final training loss:  0.0156349876119

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = range(num_training, num_training + num_validation)
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = range(num_training)
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = range(num_test)
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Validation data shape: ', X_val.shape
print 'Validation labels shape: ', y_val.shape
print 'Test data shape: ', X_test.shape
print 'Test labels shape: ', y_test.shape
# Out:
# Train data shape:  (49000L, 3072L)
# Train labels shape:  (49000L,)
# Validation data shape:  (1000L, 3072L)
# Validation labels shape:  (1000L,)
# Test data shape:  (1000L, 3072L)
# Test labels shape:  (1000L,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD with momentum. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=1000, batch_size=200,
            learning_rate=1e-4, learning_rate_decay=0.95,
            reg=0.5, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print 'Validation accuracy: ', val_acc
# Out:
# Permutation:  [18476 16112  7199 ..., 38666 13508 42119]
# iteration 0 / 1000: loss 2.302989
# iteration 100 / 1000: loss 2.302626
# iteration 200 / 1000: loss 2.298560
# iteration 300 / 1000: loss 2.271531
# iteration 400 / 1000: loss 2.216673
# iteration 500 / 1000: loss 2.060691
# iteration 600 / 1000: loss 2.128291
# iteration 700 / 1000: loss 2.124426
# iteration 800 / 1000: loss 1.988877
# iteration 900 / 1000: loss 2.041583
# Validation accuracy:  0.284

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.29 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.show()

# %%
from cs231n.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
  W1 = net.params['W1']
  W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
  plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
  plt.gca().axis('off')
  plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 52% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can, with a fully-connected Neural Network. For every 1% above 52% on the Test set we will award you with one extra bonus point. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %%
best_net = None # store the best model into this 

results = {}
best_val = -1
learning_rates = [1e-5, 1e-4, 1e-3]#, 1e-3]#, 1e-2, 1e-1, 1]
regularization_strengths = [0.1, 0.5, 10]#[0.1, 0.3, 0.5, 0.9, 1.0]
learning_rate_decay=0.95
hidden_sizes = [100, 200, 300, 400, 500]


input_size = 32 * 32 * 3
#hidden_size = 50
num_classes = 10

for learning_rate in learning_rates:
#for learning_rate in np.logspace(-4, 2, num=7):
    for reg in regularization_strengths:
    #for reg in np.logspace(4, 5, num=7):
        for hidden_size in hidden_sizes:
            print '-----------------------------------------'
            print 'Start NN lr %e reg %e hidden_size %f ' % (learning_rate, reg, hidden_size)

            net = TwoLayerNet(input_size, hidden_size, num_classes)

            # Train the network
            stats = net.train(X_train, y_train, X_val, y_val,
                num_iters=1000, batch_size=200,
                learning_rate=learning_rate, learning_rate_decay=learning_rate_decay,
                reg=reg, verbose=True)

            # Predict on the validation set
            #val_acc = (net.predict(X_val) == y_val).mean()
            #print 'Validation accuracy: ', val_acc

            y_train_pred = net.predict(X_train)
            train_acc = np.mean(y_train == y_train_pred)
            print 'training accuracy: %f' % (train_acc, )

            y_val_pred = net.predict(X_val)
            val_acc = np.mean(y_val == y_val_pred)
            print 'validation accuracy: %f' % (val_acc, )

            results[(learning_rate, reg, hidden_size)] = (train_acc, val_acc)

            if val_acc > best_val:
                best_val = val_acc
                best_net = net




################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg, hidden_size in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg, hidden_size)]
    print 'lr %e reg %e hidden_size %f train accuracy: %f val accuracy: %f' % (
                lr, reg, hidden_size, train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################
pass
#################################################################################
#                               END OF YOUR CODE                                #
#################################################################################
# Out:
# -----------------------------------------
# Start NN lr 1.000000e-05 reg 1.000000e-01 hidden_size 100.000000
# Permutation:  [14315 12252 43586 ..., 24931 40482 13829]
# iteration 0 / 1000: loss 2.302735
# iteration 100 / 1000: loss 2.302681
# iteration 200 / 1000: loss 2.302635
# iteration 300 / 1000: loss 2.302614
# iteration 400 / 1000: loss 2.302601
# iteration 500 / 1000: loss 2.302512
# iteration 600 / 1000: loss 2.302371
# iteration 700 / 1000: loss 2.302421
# iteration 800 / 1000: loss 2.302255
# iteration 900 / 1000: loss 2.302165
# training accuracy: 0.205898
# validation accuracy: 0.211000
# -----------------------------------------
# Start NN lr 1.000000e-05 reg 1.000000e-01 hidden_size 200.000000
# Permutation:  [12510 31472 19458 ..., 47144 33962 24648]
# iteration 0 / 1000: loss 2.302907
# iteration 100 / 1000: loss 2.302826
# iteration 200 / 1000: loss 2.302728
# iteration 300 / 1000: loss 2.302656
# iteration 400 / 1000: loss 2.302556
# iteration 500 / 1000: loss 2.302429
# iteration 600 / 1000: loss 2.302370
# iteration 700 / 1000: loss 2.302037
# iteration 800 / 1000: loss 2.301939
# iteration 900 / 1000: loss 2.301915
# training accuracy: 0.226796
# validation accuracy: 0.234000
# -----------------------------------------
# Start NN lr 1.000000e-05 reg 1.000000e-01 hidden_size 300.000000
# Permutation:  [ 7184 42090  7593 ..., 47239  7636 14952]
# iteration 0 / 1000: loss 2.303042
# iteration 100 / 1000: loss 2.302957
# iteration 200 / 1000: loss 2.302845
# iteration 300 / 1000: loss 2.302673
# iteration 400 / 1000: loss 2.302584
# iteration 500 / 1000: loss 2.302540
# iteration 600 / 1000: loss 2.302062
# iteration 700 / 1000: loss 2.301686
# iteration 800 / 1000: loss 2.301653
# iteration 900 / 1000: loss 2.301317
# training accuracy: 0.221184
# validation accuracy: 0.239000
# -----------------------------------------
# Start NN lr 1.000000e-05 reg 1.000000e-01 hidden_size 400.000000
# Permutation:  [29335 41911 13037 ..., 18217 40636 38455]
# iteration 0 / 1000: loss 2.303175
# iteration 100 / 1000: loss 2.302969
# iteration 200 / 1000: loss 2.302768
# iteration 300 / 1000: loss 2.302638
# iteration 400 / 1000: loss 2.302530
# iteration 500 / 1000: loss 2.301903
# iteration 600 / 1000: loss 2.301737
# iteration 700 / 1000: loss 2.301688
# iteration 800 / 1000: loss 2.301123
# iteration 900 / 1000: loss 2.300530
# training accuracy: 0.209469
# validation accuracy: 0.230000
# -----------------------------------------
# Start NN lr 1.000000e-05 reg 1.000000e-01 hidden_size 500.000000
# Permutation:  [21397 26867 21577 ..., 34673   793 10333]
# iteration 0 / 1000: loss 2.303398
# iteration 100 / 1000: loss 2.303111
# iteration 200 / 1000: loss 2.302896
# iteration 300 / 1000: loss 2.302809
# iteration 400 / 1000: loss 2.302675
# iteration 500 / 1000: loss 2.302022
# iteration 600 / 1000: loss 2.301971
# iteration 700 / 1000: loss 2.301489
# iteration 800 / 1000: loss 2.300336
# iteration 900 / 1000: loss 2.300625
# training accuracy: 0.233408
# validation accuracy: 0.244000
# -----------------------------------------
# Start NN lr 1.000000e-05 reg 5.000000e-01 hidden_size 100.000000
# Permutation:  [18165 13579 45643 ..., 47531 34760 41418]
# iteration 0 / 1000: loss 2.303356
# iteration 100 / 1000: loss 2.303293
# iteration 200 / 1000: loss 2.303246
# iteration 300 / 1000: loss 2.303194
# iteration 400 / 1000: loss 2.303168
# iteration 500 / 1000: loss 2.303078
# iteration 600 / 1000: loss 2.303039
# iteration 700 / 1000: loss 2.302807
# iteration 800 / 1000: loss 2.302909
# iteration 900 / 1000: loss 2.302648
# training accuracy: 0.247388
# validation accuracy: 0.257000
# -----------------------------------------
# Start NN lr 1.000000e-05 reg 5.000000e-01 hidden_size 200.000000
# Permutation:  [16295  9636  1338 ...,  5289 14805 37631]
# iteration 0 / 1000: loss 2.304160
# iteration 100 / 1000: loss 2.304102
# iteration 200 / 1000: loss 2.303958
# iteration 300 / 1000: loss 2.303857
# iteration 400 / 1000: loss 2.303778
# iteration 500 / 1000: loss 2.303618
# iteration 600 / 1000: loss 2.303483
# iteration 700 / 1000: loss 2.303317
# iteration 800 / 1000: loss 2.302920
# iteration 900 / 1000: loss 2.302844
# training accuracy: 0.206306
# validation accuracy: 0.219000
# -----------------------------------------
# Start NN lr 1.000000e-05 reg 5.000000e-01 hidden_size 300.000000
# Permutation:  [18768 15555 42419 ..., 20854 11972 31710]
# iteration 0 / 1000: loss 2.304989
# iteration 100 / 1000: loss 2.304829
# iteration 200 / 1000: loss 2.304674
# iteration 300 / 1000: loss 2.304437
# iteration 400 / 1000: loss 2.304339
# iteration 500 / 1000: loss 2.304293
# iteration 600 / 1000: loss 2.304154
# iteration 700 / 1000: loss 2.303703
# iteration 800 / 1000: loss 2.303346
# iteration 900 / 1000: loss 2.302877
# training accuracy: 0.228469
# validation accuracy: 0.245000
# -----------------------------------------
# Start NN lr 1.000000e-05 reg 5.000000e-01 hidden_size 400.000000
# Permutation:  [17164 43004 40235 ...,  2419  2261 31191]
# iteration 0 / 1000: loss 2.305698
# iteration 100 / 1000: loss 2.305543
# iteration 200 / 1000: loss 2.305380
# iteration 300 / 1000: loss 2.305085
# iteration 400 / 1000: loss 2.304731
# iteration 500 / 1000: loss 2.304829
# iteration 600 / 1000: loss 2.304201
# iteration 700 / 1000: loss 2.304090
# iteration 800 / 1000: loss 2.303338
# iteration 900 / 1000: loss 2.302996
# training accuracy: 0.226531
# validation accuracy: 0.249000
# -----------------------------------------
# Start NN lr 1.000000e-05 reg 5.000000e-01 hidden_size 500.000000
# Permutation:  [23332  3218  5395 ..., 40454 35613 19169]
# iteration 0 / 1000: loss 2.306502
# iteration 100 / 1000: loss 2.306246
# iteration 200 / 1000: loss 2.306100
# iteration 300 / 1000: loss 2.305781
# iteration 400 / 1000: loss 2.305591
# iteration 500 / 1000: loss 2.305145
# iteration 600 / 1000: loss 2.304867
# iteration 700 / 1000: loss 2.304432
# iteration 800 / 1000: loss 2.303873
# iteration 900 / 1000: loss 2.303933
# training accuracy: 0.223204
# validation accuracy: 0.241000
# -----------------------------------------
# Start NN lr 1.000000e-05 reg 1.000000e+01 hidden_size 100.000000
# Permutation:  [ 2427 31500 43171 ..., 24211 16964 43391]
# iteration 0 / 1000: loss 2.318060
# iteration 100 / 1000: loss 2.317732
# iteration 200 / 1000: loss 2.317412
# iteration 300 / 1000: loss 2.317099
# iteration 400 / 1000: loss 2.316794
# iteration 500 / 1000: loss 2.316522
# iteration 600 / 1000: loss 2.316161
# iteration 700 / 1000: loss 2.315877
# iteration 800 / 1000: loss 2.315615
# iteration 900 / 1000: loss 2.315307
# training accuracy: 0.230633
# validation accuracy: 0.254000
# -----------------------------------------
# Start NN lr 1.000000e-05 reg 1.000000e+01 hidden_size 200.000000
# Permutation:  [46135 22271 21118 ..., 17016 24402 45691]
# iteration 0 / 1000: loss 2.333441
# iteration 100 / 1000: loss 2.332715
# iteration 200 / 1000: loss 2.332045
# iteration 300 / 1000: loss 2.331418
# iteration 400 / 1000: loss 2.330809
# iteration 500 / 1000: loss 2.330091
# iteration 600 / 1000: loss 2.329587
# iteration 700 / 1000: loss 2.329013
# iteration 800 / 1000: loss 2.328357
# iteration 900 / 1000: loss 2.327784
# training accuracy: 0.239041
# validation accuracy: 0.257000
# -----------------------------------------
# Start NN lr 1.000000e-05 reg 1.000000e+01 hidden_size 300.000000
# Permutation:  [20845 48590  9017 ...,  4888 33229 42629]
# iteration 0 / 1000: loss 2.348895
# iteration 100 / 1000: loss 2.347848
# iteration 200 / 1000: loss 2.346824
# iteration 300 / 1000: loss 2.345958
# iteration 400 / 1000: loss 2.345024
# iteration 500 / 1000: loss 2.344059
# iteration 600 / 1000: loss 2.343247
# iteration 700 / 1000: loss 2.342181
# iteration 800 / 1000: loss 2.341257
# iteration 900 / 1000: loss 2.340427
# training accuracy: 0.217878
# validation accuracy: 0.233000
# -----------------------------------------
# Start NN lr 1.000000e-05 reg 1.000000e+01 hidden_size 400.000000
# Permutation:  [14065 33753  6175 ..., 33598 29966 23344]
# iteration 0 / 1000: loss 2.364095
# iteration 100 / 1000: loss 2.362716
# iteration 200 / 1000: loss 2.361386
# iteration 300 / 1000: loss 2.360235
# iteration 400 / 1000: loss 2.358960
# iteration 500 / 1000: loss 2.357722
# iteration 600 / 1000: loss 2.356553
# iteration 700 / 1000: loss 2.355541
# iteration 800 / 1000: loss 2.354747
# iteration 900 / 1000: loss 2.352984
# training accuracy: 0.218592
# validation accuracy: 0.241000
# -----------------------------------------
# Start NN lr 1.000000e-05 reg 1.000000e+01 hidden_size 500.000000
# Permutation:  [17442 17636 40428 ..., 29673  6868 32316]
# iteration 0 / 1000: loss 2.379640
# iteration 100 / 1000: loss 2.378101
# iteration 200 / 1000: loss 2.376380
# iteration 300 / 1000: loss 2.374773
# iteration 400 / 1000: loss 2.373153
# iteration 500 / 1000: loss 2.371645
# iteration 600 / 1000: loss 2.370588
# iteration 700 / 1000: loss 2.368471
# iteration 800 / 1000: loss 2.367866
# iteration 900 / 1000: loss 2.366061
# training accuracy: 0.228000
# validation accuracy: 0.249000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 1.000000e-01 hidden_size 100.000000
# Permutation:  [24897 42258 26846 ..., 37346 46487  5595]
# iteration 0 / 1000: loss 2.302713
# iteration 100 / 1000: loss 2.301639
# iteration 200 / 1000: loss 2.292908
# iteration 300 / 1000: loss 2.216545
# iteration 400 / 1000: loss 2.173374
# iteration 500 / 1000: loss 2.113829
# iteration 600 / 1000: loss 2.069244
# iteration 700 / 1000: loss 1.901054
# iteration 800 / 1000: loss 1.996125
# iteration 900 / 1000: loss 2.009894
# training accuracy: 0.297041
# validation accuracy: 0.299000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 1.000000e-01 hidden_size 200.000000
# Permutation:  [ 9143 28431 47707 ..., 14913 31369 41394]
# iteration 0 / 1000: loss 2.302870
# iteration 100 / 1000: loss 2.301173
# iteration 200 / 1000: loss 2.287094
# iteration 300 / 1000: loss 2.224375
# iteration 400 / 1000: loss 2.123370
# iteration 500 / 1000: loss 2.106733
# iteration 600 / 1000: loss 2.031553
# iteration 700 / 1000: loss 2.001206
# iteration 800 / 1000: loss 2.010501
# iteration 900 / 1000: loss 1.843928
# training accuracy: 0.309531
# validation accuracy: 0.311000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 1.000000e-01 hidden_size 300.000000
# Permutation:  [42920 43139 33771 ..., 34767 25243 41900]
# iteration 0 / 1000: loss 2.303037
# iteration 100 / 1000: loss 2.300634
# iteration 200 / 1000: loss 2.283696
# iteration 300 / 1000: loss 2.170312
# iteration 400 / 1000: loss 2.108758
# iteration 500 / 1000: loss 2.020832
# iteration 600 / 1000: loss 1.966421
# iteration 700 / 1000: loss 1.992561
# iteration 800 / 1000: loss 2.027048
# iteration 900 / 1000: loss 1.965726
# training accuracy: 0.315163
# validation accuracy: 0.306000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 1.000000e-01 hidden_size 400.000000
# Permutation:  [ 5202 30690  5760 ...,  3212  7077  7859]
# iteration 0 / 1000: loss 2.303150
# iteration 100 / 1000: loss 2.298914
# iteration 200 / 1000: loss 2.272929
# iteration 300 / 1000: loss 2.153102
# iteration 400 / 1000: loss 2.140611
# iteration 500 / 1000: loss 2.050201
# iteration 600 / 1000: loss 1.964434
# iteration 700 / 1000: loss 1.961540
# iteration 800 / 1000: loss 1.918708
# iteration 900 / 1000: loss 1.914423
# training accuracy: 0.320429
# validation accuracy: 0.309000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 1.000000e-01 hidden_size 500.000000
# Permutation:  [45007 46330 45647 ...,  3129  3140 35548]
# iteration 0 / 1000: loss 2.303409
# iteration 100 / 1000: loss 2.297740
# iteration 200 / 1000: loss 2.250831
# iteration 300 / 1000: loss 2.177937
# iteration 400 / 1000: loss 2.088574
# iteration 500 / 1000: loss 2.035273
# iteration 600 / 1000: loss 2.062650
# iteration 700 / 1000: loss 2.026619
# iteration 800 / 1000: loss 2.014382
# iteration 900 / 1000: loss 1.916680
# training accuracy: 0.322429
# validation accuracy: 0.314000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 5.000000e-01 hidden_size 100.000000
# Permutation:  [23540 21996 22010 ..., 48948 42300 29498]
# iteration 0 / 1000: loss 2.303372
# iteration 100 / 1000: loss 2.302407
# iteration 200 / 1000: loss 2.291788
# iteration 300 / 1000: loss 2.228197
# iteration 400 / 1000: loss 2.193738
# iteration 500 / 1000: loss 2.076723
# iteration 600 / 1000: loss 1.999577
# iteration 700 / 1000: loss 2.054402
# iteration 800 / 1000: loss 2.028731
# iteration 900 / 1000: loss 1.951862
# training accuracy: 0.290163
# validation accuracy: 0.290000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 5.000000e-01 hidden_size 200.000000
# Permutation:  [ 4239  2622 46366 ..., 11206 39174  1909]
# iteration 0 / 1000: loss 2.304083
# iteration 100 / 1000: loss 2.302352
# iteration 200 / 1000: loss 2.285103
# iteration 300 / 1000: loss 2.239814
# iteration 400 / 1000: loss 2.155077
# iteration 500 / 1000: loss 2.036049
# iteration 600 / 1000: loss 2.043011
# iteration 700 / 1000: loss 2.024145
# iteration 800 / 1000: loss 2.019778
# iteration 900 / 1000: loss 1.926460
# training accuracy: 0.306102
# validation accuracy: 0.302000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 5.000000e-01 hidden_size 300.000000
# Permutation:  [10793 17444 12191 ..., 30503  8967 20608]
# iteration 0 / 1000: loss 2.304882
# iteration 100 / 1000: loss 2.303039
# iteration 200 / 1000: loss 2.271001
# iteration 300 / 1000: loss 2.221361
# iteration 400 / 1000: loss 2.092920
# iteration 500 / 1000: loss 2.087834
# iteration 600 / 1000: loss 2.034391
# iteration 700 / 1000: loss 2.040943
# iteration 800 / 1000: loss 1.937821
# iteration 900 / 1000: loss 1.970888
# training accuracy: 0.310857
# validation accuracy: 0.304000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 5.000000e-01 hidden_size 400.000000
# Permutation:  [43840 25282 24857 ...,  9816 20804   462]
# iteration 0 / 1000: loss 2.305585
# iteration 100 / 1000: loss 2.302437
# iteration 200 / 1000: loss 2.272489
# iteration 300 / 1000: loss 2.195299
# iteration 400 / 1000: loss 2.154070
# iteration 500 / 1000: loss 2.050043
# iteration 600 / 1000: loss 2.004317
# iteration 700 / 1000: loss 1.979181
# iteration 800 / 1000: loss 2.010939
# iteration 900 / 1000: loss 1.913461
# training accuracy: 0.319347
# validation accuracy: 0.315000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 5.000000e-01 hidden_size 500.000000
# Permutation:  [29759  1476 31914 ..., 37162  1811 47730]
# iteration 0 / 1000: loss 2.306485
# iteration 100 / 1000: loss 2.302169
# iteration 200 / 1000: loss 2.269243
# iteration 300 / 1000: loss 2.179996
# iteration 400 / 1000: loss 2.079252
# iteration 500 / 1000: loss 2.103135
# iteration 600 / 1000: loss 1.992619
# iteration 700 / 1000: loss 2.095886
# iteration 800 / 1000: loss 1.859226
# iteration 900 / 1000: loss 1.904458
# training accuracy: 0.322653
# validation accuracy: 0.318000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 1.000000e+01 hidden_size 100.000000
# Permutation:  [44351 45685  9290 ..., 17344 44443 32255]
# iteration 0 / 1000: loss 2.317988
# iteration 100 / 1000: loss 2.314611
# iteration 200 / 1000: loss 2.307077
# iteration 300 / 1000: loss 2.260848
# iteration 400 / 1000: loss 2.221259
# iteration 500 / 1000: loss 2.225698
# iteration 600 / 1000: loss 2.149858
# iteration 700 / 1000: loss 2.097398
# iteration 800 / 1000: loss 2.040714
# iteration 900 / 1000: loss 2.032974
# training accuracy: 0.266122
# validation accuracy: 0.272000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 1.000000e+01 hidden_size 200.000000
# Permutation:  [48151 19124 28446 ..., 26264 24677  1761]
# iteration 0 / 1000: loss 2.333418
# iteration 100 / 1000: loss 2.326740
# iteration 200 / 1000: loss 2.314009
# iteration 300 / 1000: loss 2.228417
# iteration 400 / 1000: loss 2.205306
# iteration 500 / 1000: loss 2.178503
# iteration 600 / 1000: loss 2.052853
# iteration 700 / 1000: loss 2.151673
# iteration 800 / 1000: loss 2.024521
# iteration 900 / 1000: loss 2.023431
# training accuracy: 0.277163
# validation accuracy: 0.281000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 1.000000e+01 hidden_size 300.000000
# Permutation:  [29016 42792   979 ..., 27539 46444  5336]
# iteration 0 / 1000: loss 2.348793
# iteration 100 / 1000: loss 2.339136
# iteration 200 / 1000: loss 2.313407
# iteration 300 / 1000: loss 2.256947
# iteration 400 / 1000: loss 2.216121
# iteration 500 / 1000: loss 2.139118
# iteration 600 / 1000: loss 2.112516
# iteration 700 / 1000: loss 2.085041
# iteration 800 / 1000: loss 2.056558
# iteration 900 / 1000: loss 2.017319
# training accuracy: 0.280571
# validation accuracy: 0.282000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 1.000000e+01 hidden_size 400.000000
# Permutation:  [39283 13287 37694 ..., 20407    84 34322]
# iteration 0 / 1000: loss 2.364135
# iteration 100 / 1000: loss 2.350934
# iteration 200 / 1000: loss 2.323524
# iteration 300 / 1000: loss 2.258976
# iteration 400 / 1000: loss 2.187097
# iteration 500 / 1000: loss 2.151255
# iteration 600 / 1000: loss 2.066825
# iteration 700 / 1000: loss 2.129542
# iteration 800 / 1000: loss 2.129395
# iteration 900 / 1000: loss 1.950873
# training accuracy: 0.284082
# validation accuracy: 0.283000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 1.000000e+01 hidden_size 500.000000
# Permutation:  [28649 48932  9959 ..., 41341 40020 43679]
# iteration 0 / 1000: loss 2.379659
# iteration 100 / 1000: loss 2.363190
# iteration 200 / 1000: loss 2.329431
# iteration 300 / 1000: loss 2.255310
# iteration 400 / 1000: loss 2.156957
# iteration 500 / 1000: loss 2.248050
# iteration 600 / 1000: loss 2.136843
# iteration 700 / 1000: loss 2.133953
# iteration 800 / 1000: loss 2.110228
# iteration 900 / 1000: loss 2.067886
# training accuracy: 0.292490
# validation accuracy: 0.288000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 1.000000e-01 hidden_size 100.000000
# Permutation:  [  539 25207 30156 ..., 11428 30526 20140]
# iteration 0 / 1000: loss 2.302790
# iteration 100 / 1000: loss 1.959290
# iteration 200 / 1000: loss 1.787613
# iteration 300 / 1000: loss 1.692483
# iteration 400 / 1000: loss 1.610871
# iteration 500 / 1000: loss 1.670577
# iteration 600 / 1000: loss 1.460159
# iteration 700 / 1000: loss 1.550173
# iteration 800 / 1000: loss 1.566297
# iteration 900 / 1000: loss 1.569337
# training accuracy: 0.503673
# validation accuracy: 0.481000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 1.000000e-01 hidden_size 200.000000
# Permutation:  [24481 39156 15234 ..., 29307 26522 17484]
# iteration 0 / 1000: loss 2.302927
# iteration 100 / 1000: loss 1.961855
# iteration 200 / 1000: loss 1.712487
# iteration 300 / 1000: loss 1.601545
# iteration 400 / 1000: loss 1.607919
# iteration 500 / 1000: loss 1.598232
# iteration 600 / 1000: loss 1.544949
# iteration 700 / 1000: loss 1.452468
# iteration 800 / 1000: loss 1.488499
# iteration 900 / 1000: loss 1.326493
# training accuracy: 0.512408
# validation accuracy: 0.486000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 1.000000e-01 hidden_size 300.000000
# Permutation:  [45422 37538  8915 ..., 48402 17330 30535]
# iteration 0 / 1000: loss 2.303006
# iteration 100 / 1000: loss 1.867753
# iteration 200 / 1000: loss 1.887460
# iteration 300 / 1000: loss 1.706209
# iteration 400 / 1000: loss 1.730385
# iteration 500 / 1000: loss 1.617020
# iteration 600 / 1000: loss 1.478874
# iteration 700 / 1000: loss 1.599217
# iteration 800 / 1000: loss 1.415613
# iteration 900 / 1000: loss 1.365733
# training accuracy: 0.518531
# validation accuracy: 0.498000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 1.000000e-01 hidden_size 400.000000
# Permutation:  [ 4863  2402 36640 ...,  1310  1677 23094]
# iteration 0 / 1000: loss 2.303201
# iteration 100 / 1000: loss 1.952302
# iteration 200 / 1000: loss 1.684244
# iteration 300 / 1000: loss 1.639299
# iteration 400 / 1000: loss 1.535955
# iteration 500 / 1000: loss 1.453094
# iteration 600 / 1000: loss 1.490739
# iteration 700 / 1000: loss 1.554983
# iteration 800 / 1000: loss 1.356857
# iteration 900 / 1000: loss 1.593019
# training accuracy: 0.518776
# validation accuracy: 0.493000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 1.000000e-01 hidden_size 500.000000
# Permutation:  [18291 34992 42547 ...,  8254  9594 36017]
# iteration 0 / 1000: loss 2.303418
# iteration 100 / 1000: loss 1.913367
# iteration 200 / 1000: loss 1.846220
# iteration 300 / 1000: loss 1.639664
# iteration 400 / 1000: loss 1.580147
# iteration 500 / 1000: loss 1.645639
# iteration 600 / 1000: loss 1.573812
# iteration 700 / 1000: loss 1.542805
# iteration 800 / 1000: loss 1.370866
# iteration 900 / 1000: loss 1.406854
# training accuracy: 0.529143
# validation accuracy: 0.487000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 5.000000e-01 hidden_size 100.000000
# Permutation:  [45271 39840  4915 ..., 46938 44390 47709]
# iteration 0 / 1000: loss 2.303376
# iteration 100 / 1000: loss 2.040287
# iteration 200 / 1000: loss 1.761899
# iteration 300 / 1000: loss 1.765133
# iteration 400 / 1000: loss 1.682552
# iteration 500 / 1000: loss 1.544039
# iteration 600 / 1000: loss 1.505416
# iteration 700 / 1000: loss 1.634441
# iteration 800 / 1000: loss 1.566027
# iteration 900 / 1000: loss 1.507538
# training accuracy: 0.500612
# validation accuracy: 0.473000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 5.000000e-01 hidden_size 200.000000
# Permutation:  [27575 18002 33460 ..., 18938    70 43164]
# iteration 0 / 1000: loss 2.304110
# iteration 100 / 1000: loss 1.848163
# iteration 200 / 1000: loss 1.786361
# iteration 300 / 1000: loss 1.627234
# iteration 400 / 1000: loss 1.589555
# iteration 500 / 1000: loss 1.602495
# iteration 600 / 1000: loss 1.549696
# iteration 700 / 1000: loss 1.456508
# iteration 800 / 1000: loss 1.331189
# iteration 900 / 1000: loss 1.424185
# training accuracy: 0.507714
# validation accuracy: 0.467000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 5.000000e-01 hidden_size 300.000000
# Permutation:  [30376  7731  1313 ..., 19656  1690 14032]
# iteration 0 / 1000: loss 2.304873
# iteration 100 / 1000: loss 1.832616
# iteration 200 / 1000: loss 1.755341
# iteration 300 / 1000: loss 1.626465
# iteration 400 / 1000: loss 1.605071
# iteration 500 / 1000: loss 1.619265
# iteration 600 / 1000: loss 1.564107
# iteration 700 / 1000: loss 1.539913
# iteration 800 / 1000: loss 1.562397
# iteration 900 / 1000: loss 1.598396
# training accuracy: 0.508531
# validation accuracy: 0.499000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 5.000000e-01 hidden_size 400.000000
# Permutation:  [37998 42075 36925 ..., 39460 27004  8630]
# iteration 0 / 1000: loss 2.305728
# iteration 100 / 1000: loss 1.990851
# iteration 200 / 1000: loss 1.837931
# iteration 300 / 1000: loss 1.656545
# iteration 400 / 1000: loss 1.702259
# iteration 500 / 1000: loss 1.562331
# iteration 600 / 1000: loss 1.579311
# iteration 700 / 1000: loss 1.555306
# iteration 800 / 1000: loss 1.401139
# iteration 900 / 1000: loss 1.473913
# training accuracy: 0.513286
# validation accuracy: 0.483000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 5.000000e-01 hidden_size 500.000000
# Permutation:  [28384 44242 37172 ..., 39100  7504  1979]
# iteration 0 / 1000: loss 2.306522
# iteration 100 / 1000: loss 1.836500
# iteration 200 / 1000: loss 1.776130
# iteration 300 / 1000: loss 1.674314
# iteration 400 / 1000: loss 1.556402
# iteration 500 / 1000: loss 1.591867
# iteration 600 / 1000: loss 1.673798
# iteration 700 / 1000: loss 1.533815
# iteration 800 / 1000: loss 1.498727
# iteration 900 / 1000: loss 1.466790
# training accuracy: 0.513347
# validation accuracy: 0.482000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 1.000000e+01 hidden_size 100.000000
# Permutation:  [25974 32302   298 ..., 29955  6508 14598]
# iteration 0 / 1000: loss 2.317971
# iteration 100 / 1000: loss 2.053389
# iteration 200 / 1000: loss 1.942441
# iteration 300 / 1000: loss 1.923100
# iteration 400 / 1000: loss 2.080053
# iteration 500 / 1000: loss 1.908108
# iteration 600 / 1000: loss 1.983489
# iteration 700 / 1000: loss 2.007075
# iteration 800 / 1000: loss 2.096768
# iteration 900 / 1000: loss 1.975794
# training accuracy: 0.392857
# validation accuracy: 0.390000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 1.000000e+01 hidden_size 200.000000
# Permutation:  [19568  4556 46418 ..., 46695 12559 18037]
# iteration 0 / 1000: loss 2.333532
# iteration 100 / 1000: loss 2.095762
# iteration 200 / 1000: loss 1.943001
# iteration 300 / 1000: loss 1.936212
# iteration 400 / 1000: loss 2.013087
# iteration 500 / 1000: loss 1.960488
# iteration 600 / 1000: loss 1.995404
# iteration 700 / 1000: loss 2.049322
# iteration 800 / 1000: loss 1.929928
# iteration 900 / 1000: loss 1.973068
# training accuracy: 0.390735
# validation accuracy: 0.397000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 1.000000e+01 hidden_size 300.000000
# Permutation:  [25187 23970 33605 ..., 18177  7437 48905]
# iteration 0 / 1000: loss 2.348900
# iteration 100 / 1000: loss 2.041197
# iteration 200 / 1000: loss 1.897471
# iteration 300 / 1000: loss 1.951010
# iteration 400 / 1000: loss 2.021473
# iteration 500 / 1000: loss 1.953090
# iteration 600 / 1000: loss 2.065543
# iteration 700 / 1000: loss 1.985481
# iteration 800 / 1000: loss 2.026744
# iteration 900 / 1000: loss 1.926459
# training accuracy: 0.393245
# validation accuracy: 0.396000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 1.000000e+01 hidden_size 400.000000
# Permutation:  [33628 34248 31847 ..., 27485 26852 24570]
# iteration 0 / 1000: loss 2.364130
# iteration 100 / 1000: loss 2.061644
# iteration 200 / 1000: loss 1.998751
# iteration 300 / 1000: loss 1.960913
# iteration 400 / 1000: loss 2.026807
# iteration 500 / 1000: loss 2.013478
# iteration 600 / 1000: loss 1.996793
# iteration 700 / 1000: loss 1.875736
# iteration 800 / 1000: loss 2.031754
# iteration 900 / 1000: loss 1.972918
# training accuracy: 0.390939
# validation accuracy: 0.386000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 1.000000e+01 hidden_size 500.000000
# Permutation:  [35678 17485  7120 ...,  2485 14579 22932]
# iteration 0 / 1000: loss 2.379753
# iteration 100 / 1000: loss 2.019249
# iteration 200 / 1000: loss 2.008795
# iteration 300 / 1000: loss 1.966555
# iteration 400 / 1000: loss 1.883451
# iteration 500 / 1000: loss 1.987245
# iteration 600 / 1000: loss 1.975754
# iteration 700 / 1000: loss 1.875319
# iteration 800 / 1000: loss 2.064161
# iteration 900 / 1000: loss 1.870927
# training accuracy: 0.395184
# validation accuracy: 0.392000
# lr 1.000000e-05 reg 1.000000e-01 hidden_size 100.000000 train accuracy: 0.205898 val accuracy: 0.211000
# lr 1.000000e-05 reg 1.000000e-01 hidden_size 200.000000 train accuracy: 0.226796 val accuracy: 0.234000
# lr 1.000000e-05 reg 1.000000e-01 hidden_size 300.000000 train accuracy: 0.221184 val accuracy: 0.239000
# lr 1.000000e-05 reg 1.000000e-01 hidden_size 400.000000 train accuracy: 0.209469 val accuracy: 0.230000
# lr 1.000000e-05 reg 1.000000e-01 hidden_size 500.000000 train accuracy: 0.233408 val accuracy: 0.244000
# lr 1.000000e-05 reg 5.000000e-01 hidden_size 100.000000 train accuracy: 0.247388 val accuracy: 0.257000
# lr 1.000000e-05 reg 5.000000e-01 hidden_size 200.000000 train accuracy: 0.206306 val accuracy: 0.219000
# lr 1.000000e-05 reg 5.000000e-01 hidden_size 300.000000 train accuracy: 0.228469 val accuracy: 0.245000
# lr 1.000000e-05 reg 5.000000e-01 hidden_size 400.000000 train accuracy: 0.226531 val accuracy: 0.249000
# lr 1.000000e-05 reg 5.000000e-01 hidden_size 500.000000 train accuracy: 0.223204 val accuracy: 0.241000
# lr 1.000000e-05 reg 1.000000e+01 hidden_size 100.000000 train accuracy: 0.230633 val accuracy: 0.254000
# lr 1.000000e-05 reg 1.000000e+01 hidden_size 200.000000 train accuracy: 0.239041 val accuracy: 0.257000
# lr 1.000000e-05 reg 1.000000e+01 hidden_size 300.000000 train accuracy: 0.217878 val accuracy: 0.233000
# lr 1.000000e-05 reg 1.000000e+01 hidden_size 400.000000 train accuracy: 0.218592 val accuracy: 0.241000
# lr 1.000000e-05 reg 1.000000e+01 hidden_size 500.000000 train accuracy: 0.228000 val accuracy: 0.249000
# lr 1.000000e-04 reg 1.000000e-01 hidden_size 100.000000 train accuracy: 0.297041 val accuracy: 0.299000
# lr 1.000000e-04 reg 1.000000e-01 hidden_size 200.000000 train accuracy: 0.309531 val accuracy: 0.311000
# lr 1.000000e-04 reg 1.000000e-01 hidden_size 300.000000 train accuracy: 0.315163 val accuracy: 0.306000
# lr 1.000000e-04 reg 1.000000e-01 hidden_size 400.000000 train accuracy: 0.320429 val accuracy: 0.309000
# lr 1.000000e-04 reg 1.000000e-01 hidden_size 500.000000 train accuracy: 0.322429 val accuracy: 0.314000
# lr 1.000000e-04 reg 5.000000e-01 hidden_size 100.000000 train accuracy: 0.290163 val accuracy: 0.290000
# lr 1.000000e-04 reg 5.000000e-01 hidden_size 200.000000 train accuracy: 0.306102 val accuracy: 0.302000
# lr 1.000000e-04 reg 5.000000e-01 hidden_size 300.000000 train accuracy: 0.310857 val accuracy: 0.304000
# lr 1.000000e-04 reg 5.000000e-01 hidden_size 400.000000 train accuracy: 0.319347 val accuracy: 0.315000
# lr 1.000000e-04 reg 5.000000e-01 hidden_size 500.000000 train accuracy: 0.322653 val accuracy: 0.318000
# lr 1.000000e-04 reg 1.000000e+01 hidden_size 100.000000 train accuracy: 0.266122 val accuracy: 0.272000
# lr 1.000000e-04 reg 1.000000e+01 hidden_size 200.000000 train accuracy: 0.277163 val accuracy: 0.281000
# lr 1.000000e-04 reg 1.000000e+01 hidden_size 300.000000 train accuracy: 0.280571 val accuracy: 0.282000
# lr 1.000000e-04 reg 1.000000e+01 hidden_size 400.000000 train accuracy: 0.284082 val accuracy: 0.283000
# lr 1.000000e-04 reg 1.000000e+01 hidden_size 500.000000 train accuracy: 0.292490 val accuracy: 0.288000
# lr 1.000000e-03 reg 1.000000e-01 hidden_size 100.000000 train accuracy: 0.503673 val accuracy: 0.481000
# lr 1.000000e-03 reg 1.000000e-01 hidden_size 200.000000 train accuracy: 0.512408 val accuracy: 0.486000
# lr 1.000000e-03 reg 1.000000e-01 hidden_size 300.000000 train accuracy: 0.518531 val accuracy: 0.498000
# lr 1.000000e-03 reg 1.000000e-01 hidden_size 400.000000 train accuracy: 0.518776 val accuracy: 0.493000
# lr 1.000000e-03 reg 1.000000e-01 hidden_size 500.000000 train accuracy: 0.529143 val accuracy: 0.487000
# lr 1.000000e-03 reg 5.000000e-01 hidden_size 100.000000 train accuracy: 0.500612 val accuracy: 0.473000
# lr 1.000000e-03 reg 5.000000e-01 hidden_size 200.000000 train accuracy: 0.507714 val accuracy: 0.467000
# lr 1.000000e-03 reg 5.000000e-01 hidden_size 300.000000 train accuracy: 0.508531 val accuracy: 0.499000
# lr 1.000000e-03 reg 5.000000e-01 hidden_size 400.000000 train accuracy: 0.513286 val accuracy: 0.483000
# lr 1.000000e-03 reg 5.000000e-01 hidden_size 500.000000 train accuracy: 0.513347 val accuracy: 0.482000
# lr 1.000000e-03 reg 1.000000e+01 hidden_size 100.000000 train accuracy: 0.392857 val accuracy: 0.390000
# lr 1.000000e-03 reg 1.000000e+01 hidden_size 200.000000 train accuracy: 0.390735 val accuracy: 0.397000
# lr 1.000000e-03 reg 1.000000e+01 hidden_size 300.000000 train accuracy: 0.393245 val accuracy: 0.396000
# lr 1.000000e-03 reg 1.000000e+01 hidden_size 400.000000 train accuracy: 0.390939 val accuracy: 0.386000
# lr 1.000000e-03 reg 1.000000e+01 hidden_size 500.000000 train accuracy: 0.395184 val accuracy: 0.392000
# best validation accuracy achieved during cross-validation: 0.499000

# %%
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.
#
# **We will give you extra bonus point for every 1% of accuracy above 52%.**

# %%
test_acc = (best_net.predict(X_test) == y_test).mean()
print 'Test accuracy: ', test_acc
# Out:
# Test accuracy:  0.482
