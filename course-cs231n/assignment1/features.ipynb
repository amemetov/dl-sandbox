# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
  # Load the raw CIFAR-10 data
  cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
  X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
  
  # Subsample the data
  mask = range(num_training, num_training + num_validation)
  X_val = X_train[mask]
  y_val = y_train[mask]
  mask = range(num_training)
  X_train = X_train[mask]
  y_train = y_train[mask]
  mask = range(num_test)
  X_test = X_test[mask]
  y_test = y_test[mask]

  return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for the bonus section.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

learning_rates = [1e-9, 1e-8, 1e-7]
regularization_strengths = [1e5, 1e6, 1e7]

results = {}
best_val = -1
best_svm = None

pass
################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
for learning_rate in learning_rates:
#for learning_rate in np.logspace(-4, 2, num=7):
    for reg in regularization_strengths:
    #for reg in np.logspace(4, 5, num=7):
        print '-----------------------------------------'
        print 'Start SVM lr %e reg %e ' % (learning_rate, reg)
        svm = LinearSVM()
        loss_hist = svm.train(X_train_feats, y_train, learning_rate=learning_rate, 
                              reg=reg, num_iters=1500, verbose=True)

        y_train_pred = svm.predict(X_train_feats)
        train_acc = np.mean(y_train == y_train_pred)
        print 'training accuracy: %f' % (train_acc, )

        y_val_pred = svm.predict(X_val_feats)
        val_acc = np.mean(y_val == y_val_pred)
        print 'validation accuracy: %f' % (val_acc, )
        
        results[(learning_rate, reg)] = (train_acc, val_acc)
        
        if val_acc > best_val:
            best_val = val_acc
            best_svm = svm
################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print 'lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val
# Out:
# -----------------------------------------
# Start SVM lr 1.000000e-09 reg 1.000000e+05
# Permutation:  [ 9745  2647  6968 ..., 43547 20900 34445]
# iteration 0 / 1500: loss 173.952739
# iteration 100 / 1500: loss 172.325473
# iteration 200 / 1500: loss 170.668415
# iteration 300 / 1500: loss 169.063825
# iteration 400 / 1500: loss 167.472486
# iteration 500 / 1500: loss 165.909740
# iteration 600 / 1500: loss 164.334818
# iteration 700 / 1500: loss 162.793404
# iteration 800 / 1500: loss 161.263061
# iteration 900 / 1500: loss 159.752599
# iteration 1000 / 1500: loss 158.247963
# iteration 1100 / 1500: loss 156.748492
# iteration 1200 / 1500: loss 155.300588
# iteration 1300 / 1500: loss 153.842073
# iteration 1400 / 1500: loss 152.403106
# training accuracy: 0.087020
# validation accuracy: 0.083000
# -----------------------------------------
# Start SVM lr 1.000000e-09 reg 1.000000e+06
# Permutation:  [14845  8522  3266 ..., 12930 21246 42470]
# iteration 0 / 1500: loss 1601.547175
# iteration 100 / 1500: loss 1449.969280
# iteration 200 / 1500: loss 1312.808878
# iteration 300 / 1500: loss 1188.694935
# iteration 400 / 1500: loss 1076.418244
# iteration 500 / 1500: loss 974.802058
# iteration 600 / 1500: loss 882.873773
# iteration 700 / 1500: loss 799.675254
# iteration 800 / 1500: loss 724.441592
# iteration 900 / 1500: loss 656.326242
# iteration 1000 / 1500: loss 594.714727
# iteration 1100 / 1500: loss 538.962771
# iteration 1200 / 1500: loss 488.514804
# iteration 1300 / 1500: loss 442.864590
# iteration 1400 / 1500: loss 401.576566
# training accuracy: 0.083306
# validation accuracy: 0.077000
# -----------------------------------------
# Start SVM lr 1.000000e-09 reg 1.000000e+07
# Permutation:  [43200 30911  4025 ..., 35965 10465 25295]
# iteration 0 / 1500: loss 15501.821080
# iteration 100 / 1500: loss 5694.221017
# iteration 200 / 1500: loss 2095.239508
# iteration 300 / 1500: loss 774.561541
# iteration 400 / 1500: loss 289.932670
# iteration 500 / 1500: loss 112.091012
# iteration 600 / 1500: loss 46.829869
# iteration 700 / 1500: loss 22.882539
# iteration 800 / 1500: loss 14.094537
# iteration 900 / 1500: loss 10.869544
# iteration 1000 / 1500: loss 9.686072
# iteration 1100 / 1500: loss 9.251769
# iteration 1200 / 1500: loss 9.092418
# iteration 1300 / 1500: loss 9.033938
# iteration 1400 / 1500: loss 9.012477
# training accuracy: 0.161878
# validation accuracy: 0.142000
# -----------------------------------------
# Start SVM lr 1.000000e-08 reg 1.000000e+05
# Permutation:  [24533 30752 42856 ...,  7374 14082  6775]
# iteration 0 / 1500: loss 159.685782
# iteration 100 / 1500: loss 145.339994
# iteration 200 / 1500: loss 132.370941
# iteration 300 / 1500: loss 120.622565
# iteration 400 / 1500: loss 109.988541
# iteration 500 / 1500: loss 100.388765
# iteration 600 / 1500: loss 91.696414
# iteration 700 / 1500: loss 83.814957
# iteration 800 / 1500: loss 76.681827
# iteration 900 / 1500: loss 70.258003
# iteration 1000 / 1500: loss 64.412159
# iteration 1100 / 1500: loss 59.139345
# iteration 1200 / 1500: loss 54.379794
# iteration 1300 / 1500: loss 50.057945
# iteration 1400 / 1500: loss 46.133826
# training accuracy: 0.093612
# validation accuracy: 0.083000
# -----------------------------------------
# Start SVM lr 1.000000e-08 reg 1.000000e+06
# Permutation:  [ 8868 23924 15183 ..., 46293 31722  4268]
# iteration 0 / 1500: loss 1556.228653
# iteration 100 / 1500: loss 576.769355
# iteration 200 / 1500: loss 217.341940
# iteration 300 / 1500: loss 85.453146
# iteration 400 / 1500: loss 37.054668
# iteration 500 / 1500: loss 19.293174
# iteration 600 / 1500: loss 12.778136
# iteration 700 / 1500: loss 10.386071
# iteration 800 / 1500: loss 9.508747
# iteration 900 / 1500: loss 9.186791
# iteration 1000 / 1500: loss 9.068650
# iteration 1100 / 1500: loss 9.025258
# iteration 1200 / 1500: loss 9.009305
# iteration 1300 / 1500: loss 9.003513
# iteration 1400 / 1500: loss 9.001384
# training accuracy: 0.327490
# validation accuracy: 0.312000
# -----------------------------------------
# Start SVM lr 1.000000e-08 reg 1.000000e+07
# Permutation:  [ 7838 28505 16584 ..., 22229 45433 30248]
# iteration 0 / 1500: loss 15402.512143
# iteration 100 / 1500: loss 9.539524
# iteration 200 / 1500: loss 9.000035
# iteration 300 / 1500: loss 9.000017
# iteration 400 / 1500: loss 9.000015
# iteration 500 / 1500: loss 9.000014
# iteration 600 / 1500: loss 9.000017
# iteration 700 / 1500: loss 9.000013
# iteration 800 / 1500: loss 9.000015
# iteration 900 / 1500: loss 9.000014
# iteration 1000 / 1500: loss 9.000017
# iteration 1100 / 1500: loss 9.000014
# iteration 1200 / 1500: loss 9.000015
# iteration 1300 / 1500: loss 9.000015
# iteration 1400 / 1500: loss 9.000015
# training accuracy: 0.409673
# validation accuracy: 0.408000
# -----------------------------------------
# Start SVM lr 1.000000e-07 reg 1.000000e+05
# Permutation:  [31584 45921 26044 ..., 36853 40684  9811]
# iteration 0 / 1500: loss 165.926679
# iteration 100 / 1500: loss 66.575109
# iteration 200 / 1500: loss 30.121611
# iteration 300 / 1500: loss 16.746943
# iteration 400 / 1500: loss 11.843574
# iteration 500 / 1500: loss 10.041507
# iteration 600 / 1500: loss 9.381175
# iteration 700 / 1500: loss 9.140248
# iteration 800 / 1500: loss 9.052082
# iteration 900 / 1500: loss 9.019535
# iteration 1000 / 1500: loss 9.008063
# iteration 1100 / 1500: loss 9.003649
# iteration 1200 / 1500: loss 9.002318
# iteration 1300 / 1500: loss 9.001491
# iteration 1400 / 1500: loss 9.001427
# training accuracy: 0.415796
# validation accuracy: 0.414000
# -----------------------------------------
# Start SVM lr 1.000000e-07 reg 1.000000e+06
# Permutation:  [44370 17940 27676 ..., 13751 26756 16187]
# iteration 0 / 1500: loss 1566.833276
# iteration 100 / 1500: loss 9.054866
# iteration 200 / 1500: loss 9.000154
# iteration 300 / 1500: loss 9.000145
# iteration 400 / 1500: loss 9.000149
# iteration 500 / 1500: loss 9.000165
# iteration 600 / 1500: loss 9.000148
# iteration 700 / 1500: loss 9.000150
# iteration 800 / 1500: loss 9.000148
# iteration 900 / 1500: loss 9.000140
# iteration 1000 / 1500: loss 9.000149
# iteration 1100 / 1500: loss 9.000149
# iteration 1200 / 1500: loss 9.000141
# iteration 1300 / 1500: loss 9.000130
# iteration 1400 / 1500: loss 9.000142
# training accuracy: 0.407245
# validation accuracy: 0.418000
# -----------------------------------------
# Start SVM lr 1.000000e-07 reg 1.000000e+07
# Permutation:  [ 9245 46912 37883 ..., 15476 39806 45097]
# iteration 0 / 1500: loss 15984.204331
# iteration 100 / 1500: loss 9.000021
# iteration 200 / 1500: loss 9.000024
# iteration 300 / 1500: loss 9.000022
# iteration 400 / 1500: loss 9.000021
# iteration 500 / 1500: loss 9.000023
# iteration 600 / 1500: loss 9.000022
# iteration 700 / 1500: loss 9.000023
# iteration 800 / 1500: loss 9.000024
# iteration 900 / 1500: loss 9.000021
# iteration 1000 / 1500: loss 9.000021
# iteration 1100 / 1500: loss 9.000025
# iteration 1200 / 1500: loss 9.000024
# iteration 1300 / 1500: loss 9.000020
# iteration 1400 / 1500: loss 9.000021
# training accuracy: 0.349082
# validation accuracy: 0.347000
# lr 1.000000e-09 reg 1.000000e+05 train accuracy: 0.087020 val accuracy: 0.083000
# lr 1.000000e-09 reg 1.000000e+06 train accuracy: 0.083306 val accuracy: 0.077000
# lr 1.000000e-09 reg 1.000000e+07 train accuracy: 0.161878 val accuracy: 0.142000
# lr 1.000000e-08 reg 1.000000e+05 train accuracy: 0.093612 val accuracy: 0.083000
# lr 1.000000e-08 reg 1.000000e+06 train accuracy: 0.327490 val accuracy: 0.312000
# lr 1.000000e-08 reg 1.000000e+07 train accuracy: 0.409673 val accuracy: 0.408000
# lr 1.000000e-07 reg 1.000000e+05 train accuracy: 0.415796 val accuracy: 0.414000
# lr 1.000000e-07 reg 1.000000e+06 train accuracy: 0.407245 val accuracy: 0.418000
# lr 1.000000e-07 reg 1.000000e+07 train accuracy: 0.349082 val accuracy: 0.347000
# best validation accuracy achieved during cross-validation: 0.418000

# %%
# Evaluate your trained SVM on the test set
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print test_accuracy
# Out:
# 0.413

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
print X_train_feats.shape
# Out:
# (49000L, 155L)

# %%
from cs231n.classifiers.neural_net import TwoLayerNet

input_dim = X_train_feats.shape[1]
num_classes = 10

results = {}
best_val = -1
learning_rates = [1e-10, 1e-9, 1e-8, 1e-7]#, 1e-5, 1e-4, 1e-3]
egularization_strengths = [0.1, 0.5, 1, 1e2, 1e3, 1e4, 1e5, 1e6, 1e7]
learning_rate_decay=0.95
hidden_sizes = [10, 25, 50, 100, 200]#, 300, 400, 500]


input_size = input_dim#32 * 32 * 3
num_classes = 10

#for learning_rate in learning_rates:
for learning_rate in np.logspace(-4, 2, num=7):
    #for reg in regularization_strengths:
    for reg in np.logspace(4, 5, num=7):
        for hidden_size in hidden_sizes:
            print '-----------------------------------------'
            print 'Start NN lr %e reg %e hidden_size %f ' % (learning_rate, reg, hidden_size)
            net = TwoLayerNet(input_size, hidden_size, num_classes)

            # Train the network
            stats = net.train(X_train_feats, y_train, X_val_feats, y_val,
                num_iters=1000, batch_size=200,
                learning_rate=learning_rate, learning_rate_decay=learning_rate_decay,
                reg=reg, verbose=True)

            # Predict on the validation set
            #val_acc = (net.predict(X_val) == y_val).mean()
            #print 'Validation accuracy: ', val_acc

            y_train_pred = net.predict(X_train_feats)
            train_acc = np.mean(y_train == y_train_pred)
            print 'training accuracy: %f' % (train_acc, )

            y_val_pred = net.predict(X_val_feats)
            val_acc = np.mean(y_val == y_val_pred)
            print 'validation accuracy: %f' % (val_acc, )

            results[(learning_rate, reg, hidden_size)] = (train_acc, val_acc)

            if val_acc > best_val:
                best_val = val_acc
                best_net = net



best_net = net

# Print out results.
for lr, reg, hidden_size in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg, hidden_size)]
    print 'lr %e reg %e hidden_size %f train accuracy: %f val accuracy: %f' % (
                lr, reg, hidden_size, train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val

################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 1.000000e+04 hidden_size 10.000000
# Permutation:  [ 7416  9220 35536 ..., 30782 18510  1737]
# iteration 0 / 1000: loss 2.384462
# iteration 100 / 1000: loss 2.302584
# iteration 200 / 1000: loss 2.302587
# iteration 300 / 1000: loss 2.302586
# iteration 400 / 1000: loss 2.302586
# iteration 500 / 1000: loss 2.302586
# iteration 600 / 1000: loss 2.302585
# iteration 700 / 1000: loss 2.302583
# iteration 800 / 1000: loss 2.302585
# iteration 900 / 1000: loss 2.302586
# training accuracy: 0.100449
# validation accuracy: 0.078000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 1.000000e+04 hidden_size 25.000000
# Permutation:  [39241 31742 12089 ..., 29718 42496 25120]
# iteration 0 / 1000: loss 2.507395
# iteration 100 / 1000: loss 2.302583
# iteration 200 / 1000: loss 2.302584
# iteration 300 / 1000: loss 2.302583
# iteration 400 / 1000: loss 2.302586
# iteration 500 / 1000: loss 2.302585
# iteration 600 / 1000: loss 2.302588
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302583
# iteration 900 / 1000: loss 2.302585
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 1.000000e+04 hidden_size 50.000000
# Permutation:  [45665 20471 48787 ..., 37805 14425 46045]
# iteration 0 / 1000: loss 2.715328
# iteration 100 / 1000: loss 2.302585
# iteration 200 / 1000: loss 2.302585
# iteration 300 / 1000: loss 2.302585
# iteration 400 / 1000: loss 2.302584
# iteration 500 / 1000: loss 2.302584
# iteration 600 / 1000: loss 2.302585
# iteration 700 / 1000: loss 2.302587
# iteration 800 / 1000: loss 2.302584
# iteration 900 / 1000: loss 2.302585
# training accuracy: 0.100449
# validation accuracy: 0.078000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 1.000000e+04 hidden_size 100.000000
# Permutation:  [25853 25142 32159 ..., 26809 47202 14136]
# iteration 0 / 1000: loss 3.123441
# iteration 100 / 1000: loss 2.302585
# iteration 200 / 1000: loss 2.302585
# iteration 300 / 1000: loss 2.302587
# iteration 400 / 1000: loss 2.302584
# iteration 500 / 1000: loss 2.302585
# iteration 600 / 1000: loss 2.302586
# iteration 700 / 1000: loss 2.302584
# iteration 800 / 1000: loss 2.302586
# iteration 900 / 1000: loss 2.302589
# training accuracy: 0.100429
# validation accuracy: 0.079000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 1.000000e+04 hidden_size 200.000000
# Permutation:  [44590 44070 42568 ..., 12816 45221 28265]
# iteration 0 / 1000: loss 3.968927
# iteration 100 / 1000: loss 2.302585
# iteration 200 / 1000: loss 2.302584
# iteration 300 / 1000: loss 2.302586
# iteration 400 / 1000: loss 2.302586
# iteration 500 / 1000: loss 2.302584
# iteration 600 / 1000: loss 2.302584
# iteration 700 / 1000: loss 2.302590
# iteration 800 / 1000: loss 2.302587
# iteration 900 / 1000: loss 2.302586
# training accuracy: 0.100449
# validation accuracy: 0.078000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 1.467799e+04 hidden_size 10.000000
# Permutation:  [39089 28245 19689 ..., 17705  8710 27711]
# iteration 0 / 1000: loss 2.429204
# iteration 100 / 1000: loss 2.302584
# iteration 200 / 1000: loss 2.302586
# iteration 300 / 1000: loss 2.302587
# iteration 400 / 1000: loss 2.302585
# iteration 500 / 1000: loss 2.302586
# iteration 600 / 1000: loss 2.302583
# iteration 700 / 1000: loss 2.302583
# iteration 800 / 1000: loss 2.302585
# iteration 900 / 1000: loss 2.302586
# training accuracy: 0.100449
# validation accuracy: 0.078000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 1.467799e+04 hidden_size 25.000000
# Permutation:  [36433  7604  3233 ..., 14596  4250 45932]
# iteration 0 / 1000: loss 2.605684
# iteration 100 / 1000: loss 2.302586
# iteration 200 / 1000: loss 2.302585
# iteration 300 / 1000: loss 2.302585
# iteration 400 / 1000: loss 2.302586
# iteration 500 / 1000: loss 2.302585
# iteration 600 / 1000: loss 2.302584
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302588
# iteration 900 / 1000: loss 2.302586
# training accuracy: 0.100449
# validation accuracy: 0.078000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 1.467799e+04 hidden_size 50.000000
# Permutation:  [15540  9444 31061 ..., 47486 32418  3902]
# iteration 0 / 1000: loss 2.916862
# iteration 100 / 1000: loss 2.302586
# iteration 200 / 1000: loss 2.302587
# iteration 300 / 1000: loss 2.302586
# iteration 400 / 1000: loss 2.302587
# iteration 500 / 1000: loss 2.302586
# iteration 600 / 1000: loss 2.302585
# iteration 700 / 1000: loss 2.302585
# iteration 800 / 1000: loss 2.302584
# iteration 900 / 1000: loss 2.302588
# training accuracy: 0.100429
# validation accuracy: 0.079000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 1.467799e+04 hidden_size 100.000000
# Permutation:  [ 2746  6772 37488 ..., 36199 38625 35075]
# iteration 0 / 1000: loss 3.508030
# iteration 100 / 1000: loss 2.302584
# iteration 200 / 1000: loss 2.302586
# iteration 300 / 1000: loss 2.302585
# iteration 400 / 1000: loss 2.302585
# iteration 500 / 1000: loss 2.302586
# iteration 600 / 1000: loss 2.302586
# iteration 700 / 1000: loss 2.302586
# iteration 800 / 1000: loss 2.302588
# iteration 900 / 1000: loss 2.302585
# training accuracy: 0.100449
# validation accuracy: 0.078000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 1.467799e+04 hidden_size 200.000000
# Permutation:  [22452 15975 21802 ..., 20475 38993 15725]
# iteration 0 / 1000: loss 4.722057
# iteration 100 / 1000: loss 2.302587
# iteration 200 / 1000: loss 2.302586
# iteration 300 / 1000: loss 2.302585
# iteration 400 / 1000: loss 2.302585
# iteration 500 / 1000: loss 2.302585
# iteration 600 / 1000: loss 2.302585
# iteration 700 / 1000: loss 2.302586
# iteration 800 / 1000: loss 2.302587
# iteration 900 / 1000: loss 2.302585
# training accuracy: 0.100449
# validation accuracy: 0.078000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 2.154435e+04 hidden_size 10.000000
# Permutation:  [18515 23635 43780 ..., 22383  6835  7933]
# iteration 0 / 1000: loss 2.480923
# iteration 100 / 1000: loss 2006.005612
# iteration 200 / 1000: loss 18513963.938797
# iteration 300 / 1000: loss 2557179.097938
# iteration 400 / 1000: loss 29.650462
# iteration 500 / 1000: loss 2.302658
# iteration 600 / 1000: loss 2.302537
# iteration 700 / 1000: loss 2.302651
# iteration 800 / 1000: loss 2.302503
# iteration 900 / 1000: loss 2.302618
# training accuracy: 0.099898
# validation accuracy: 0.105000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 2.154435e+04 hidden_size 25.000000
# Permutation:  [27719 31072  6325 ..., 22076 32632 24608]
# iteration 0 / 1000: loss 2.734536
# iteration 100 / 1000: loss 4855.715372
# iteration 200 / 1000: loss 44841751.673492
# iteration 300 / 1000: loss 6191563.220465
# iteration 400 / 1000: loss 68.519183
# iteration 500 / 1000: loss 2.302713
# iteration 600 / 1000: loss 2.302577
# iteration 700 / 1000: loss 2.302554
# iteration 800 / 1000: loss 2.302617
# iteration 900 / 1000: loss 2.302610
# training accuracy: 0.100429
# validation accuracy: 0.079000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 2.154435e+04 hidden_size 50.000000
# Permutation:  [35284 37312  1342 ..., 42072  3515 48736]
# iteration 0 / 1000: loss 3.192185
# iteration 100 / 1000: loss 9997.738588
# iteration 200 / 1000: loss 92341179.555904
# iteration 300 / 1000: loss 12747310.894512
# iteration 400 / 1000: loss 138.624218
# iteration 500 / 1000: loss 2.302806
# iteration 600 / 1000: loss 2.302553
# iteration 700 / 1000: loss 2.302594
# iteration 800 / 1000: loss 2.302620
# iteration 900 / 1000: loss 2.302629
# training accuracy: 0.099735
# validation accuracy: 0.113000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 2.154435e+04 hidden_size 100.000000
# Permutation:  [46789 41010  7327 ...,  5451 32435  8385]
# iteration 0 / 1000: loss 4.130005
# iteration 100 / 1000: loss 20534.907345
# iteration 200 / 1000: loss 189682480.741482
# iteration 300 / 1000: loss 26182524.297733
# iteration 400 / 1000: loss 282.300436
# iteration 500 / 1000: loss 2.303007
# iteration 600 / 1000: loss 2.302599
# iteration 700 / 1000: loss 2.302642
# iteration 800 / 1000: loss 2.302601
# iteration 900 / 1000: loss 2.302538
# training accuracy: 0.099612
# validation accuracy: 0.119000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 2.154435e+04 hidden_size 200.000000
# Permutation:  [38393  7288 42903 ..., 26771 30542 45515]
# iteration 0 / 1000: loss 5.818812
# iteration 100 / 1000: loss 39510.350211
# iteration 200 / 1000: loss inf
# iteration 300 / 1000: loss 50375930.231811
# iteration 400 / 1000: loss 541.025624
# iteration 500 / 1000: loss 2.303532
# iteration 600 / 1000: loss 2.302638
# iteration 700 / 1000: loss 2.302549
# iteration 800 / 1000: loss 2.302608
# iteration 900 / 1000: loss 2.302602
# training accuracy: 0.100449
# validation accuracy: 0.078000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 3.162278e+04 hidden_size 10.000000
# Permutation:  [40984 22646 44881 ..., 37146 29078  6339]
# iteration 0 / 1000: loss 2.561686
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss inf
# iteration 300 / 1000: loss inf
# iteration 400 / 1000: loss inf
# iteration 500 / 1000: loss inf
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 3.162278e+04 hidden_size 25.000000
# Permutation:  [18413  1788 17810 ..., 31643 33933  6716]
# iteration 0 / 1000: loss 2.956567
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss inf
# iteration 300 / 1000: loss inf
# iteration 400 / 1000: loss inf
# iteration 500 / 1000: loss inf
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 3.162278e+04 hidden_size 50.000000
# Permutation:  [ 1297  7470 29369 ..., 10316  8640 38858]
# iteration 0 / 1000: loss 3.607494
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss inf
# iteration 300 / 1000: loss inf
# iteration 400 / 1000: loss inf
# iteration 500 / 1000: loss inf
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 3.162278e+04 hidden_size 100.000000
# Permutation:  [13898 17415  1061 ..., 13321 22866 30063]
# iteration 0 / 1000: loss 4.909426
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss inf
# iteration 300 / 1000: loss inf
# iteration 400 / 1000: loss inf
# iteration 500 / 1000: loss inf
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 3.162278e+04 hidden_size 200.000000
# Permutation:  [23892 31036 45949 ..., 42940 36831 35100]
# iteration 0 / 1000: loss 7.572113
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss inf
# iteration 300 / 1000: loss inf
# iteration 400 / 1000: loss inf
# iteration 500 / 1000: loss inf
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 4.641589e+04 hidden_size 10.000000
# Permutation:  [41144  5223 41141 ..., 14492 28129 42971]
# iteration 0 / 1000: loss 2.686043
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss inf
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 4.641589e+04 hidden_size 25.000000
# Permutation:  [23645 14031   152 ..., 25425 32496 13368]
# iteration 0 / 1000: loss 3.283087
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss inf
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 4.641589e+04 hidden_size 50.000000
# Permutation:  [20178 22771 44932 ...,    62 20005 46267]
# iteration 0 / 1000: loss 4.222300
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss inf
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 4.641589e+04 hidden_size 100.000000
# Permutation:  [10758  2842 19554 ..., 18306 10021   101]
# iteration 0 / 1000: loss 6.092963
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss inf
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 4.641589e+04 hidden_size 200.000000
# Permutation:  [45597 16144  7321 ..., 27658 19686 30545]
# iteration 0 / 1000: loss 9.911693
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss inf
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 6.812921e+04 hidden_size 10.000000
# Permutation:  [39087 26519 36059 ..., 41136 39097 41666]
# iteration 0 / 1000: loss 2.873572
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss inf
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 6.812921e+04 hidden_size 25.000000
# Permutation:  [32963 48424 19307 ..., 45615 26656  3366]
# iteration 0 / 1000: loss 3.655556
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss inf
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 6.812921e+04 hidden_size 50.000000
# Permutation:  [20220 46112 19839 ..., 47906  2623 15636]
# iteration 0 / 1000: loss 5.079704
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss inf
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 6.812921e+04 hidden_size 100.000000
# Permutation:  [35802 24535 46903 ..., 18553 11512 47738]
# iteration 0 / 1000: loss 7.885482
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss inf
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 6.812921e+04 hidden_size 200.000000
# Permutation:  [47436 24128 19231 ..., 45091 29112  9910]
# iteration 0 / 1000: loss 13.582003
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss inf
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 1.000000e+05 hidden_size 10.000000
# Permutation:  [29926 14174 29872 ...,  3775  8911 31550]
# iteration 0 / 1000: loss 3.208358
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 1.000000e+05 hidden_size 25.000000
# Permutation:  [44266 22788 48912 ..., 29195 27432 37943]
# iteration 0 / 1000: loss 4.370556
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 1.000000e+05 hidden_size 50.000000
# Permutation:  [ 9499  5021 35121 ..., 35862  8868 15971]
# iteration 0 / 1000: loss 6.362031
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 1.000000e+05 hidden_size 100.000000
# Permutation:  [46448 19006  6998 ..., 44862 29738   429]
# iteration 0 / 1000: loss 10.563905
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-04 reg 1.000000e+05 hidden_size 200.000000
# Permutation:  [11480 35179 27466 ..., 21184 44790 37646]
# iteration 0 / 1000: loss 18.766184
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 1.000000e+04 hidden_size 10.000000
# Permutation:  [36090 26451   821 ..., 34342  4009  5188]
# iteration 0 / 1000: loss 2.384999
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 1.000000e+04 hidden_size 25.000000
# Permutation:  [ 3194 41393 24986 ...,  2392 44905 45074]
# iteration 0 / 1000: loss 2.519024
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 1.000000e+04 hidden_size 50.000000
# Permutation:  [  251  2298 13311 ...,  6078 39773 28938]
# iteration 0 / 1000: loss 2.716603
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 1.000000e+04 hidden_size 100.000000
# Permutation:  [10179 28904 29416 ..., 27723 41931 28960]
# iteration 0 / 1000: loss 3.132371
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 1.000000e+04 hidden_size 200.000000
# Permutation:  [32518 43037  1006 ...,  4013  7554  3615]
# iteration 0 / 1000: loss 3.966888
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 1.467799e+04 hidden_size 10.000000
# Permutation:  [15824  5347 17903 ..., 13061 33641 16639]
# iteration 0 / 1000: loss 2.423789
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 1.467799e+04 hidden_size 25.000000
# Permutation:  [29915 37034 20290 ..., 20138 20884 45047]
# iteration 0 / 1000: loss 2.595287
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 1.467799e+04 hidden_size 50.000000
# Permutation:  [44740  3890  9899 ..., 43089  6088  2285]
# iteration 0 / 1000: loss 2.902827
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 1.467799e+04 hidden_size 100.000000
# Permutation:  [39001 25675 42033 ..., 36696 24471  3241]
# iteration 0 / 1000: loss 3.501782
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 1.467799e+04 hidden_size 200.000000
# Permutation:  [ 5108  1023   704 ...,   648 29190 43041]
# iteration 0 / 1000: loss 4.716885
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 2.154435e+04 hidden_size 10.000000
# Permutation:  [44426 27328 43041 ..., 13559 17865 46404]
# iteration 0 / 1000: loss 2.481480
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 2.154435e+04 hidden_size 25.000000
# Permutation:  [ 7422 30883 12857 ..., 17006 30005 16518]
# iteration 0 / 1000: loss 2.749058
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 2.154435e+04 hidden_size 50.000000
# Permutation:  [ 9765 23613 19735 ..., 48719 17867 21034]
# iteration 0 / 1000: loss 3.210687
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 2.154435e+04 hidden_size 100.000000
# Permutation:  [13361 18396 40711 ..., 10924 42975 21931]
# iteration 0 / 1000: loss 4.061958
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 2.154435e+04 hidden_size 200.000000
# Permutation:  [33937 10328 40073 ...,  2298 15836 42488]
# iteration 0 / 1000: loss 5.849156
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 3.162278e+04 hidden_size 10.000000
# Permutation:  [10439  4676 43524 ..., 36884 16819  7102]
# iteration 0 / 1000: loss 2.584998
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 3.162278e+04 hidden_size 25.000000
# Permutation:  [29913 14072  3792 ..., 13129 16167 30677]
# iteration 0 / 1000: loss 2.949433
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 3.162278e+04 hidden_size 50.000000
# Permutation:  [30930 39260 15176 ..., 18038  4244 27995]
# iteration 0 / 1000: loss 3.607488
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 3.162278e+04 hidden_size 100.000000
# Permutation:  [14022 40327 47203 ..., 43093 23624 14405]
# iteration 0 / 1000: loss 4.892068
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 3.162278e+04 hidden_size 200.000000
# Permutation:  [13569 17542 27153 ...,  8834 10845 36245]
# iteration 0 / 1000: loss 7.462266
# iteration 100 / 1000: loss inf
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 4.641589e+04 hidden_size 10.000000
# Permutation:  [35944  7886 29425 ..., 23071 43347 24605]
# iteration 0 / 1000: loss 2.689900
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 4.641589e+04 hidden_size 25.000000
# Permutation:  [ 5007 22047 26375 ..., 26542 25718 31268]
# iteration 0 / 1000: loss 3.271128
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 4.641589e+04 hidden_size 50.000000
# Permutation:  [34015 14973  9270 ..., 37426 15575 14335]
# iteration 0 / 1000: loss 4.208490
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 4.641589e+04 hidden_size 100.000000
# Permutation:  [23821 21222 32685 ..., 23310  4796 24529]
# iteration 0 / 1000: loss 6.086066
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 4.641589e+04 hidden_size 200.000000
# Permutation:  [10227 48399 29704 ..., 36133 10607   832]
# iteration 0 / 1000: loss 9.864605
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 6.812921e+04 hidden_size 10.000000
# Permutation:  [24073 16400   855 ..., 44613 42850 38611]
# iteration 0 / 1000: loss 2.862861
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 6.812921e+04 hidden_size 25.000000
# Permutation:  [34348 38491 46618 ...,  3725  3291  8027]
# iteration 0 / 1000: loss 3.683919
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 6.812921e+04 hidden_size 50.000000
# Permutation:  [12468 25840 23303 ..., 11422 16439 30316]
# iteration 0 / 1000: loss 5.095218
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 6.812921e+04 hidden_size 100.000000
# Permutation:  [ 9695  5231 30890 ...,  4145  4740 45295]
# iteration 0 / 1000: loss 7.969444
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 6.812921e+04 hidden_size 200.000000
# Permutation:  [40217  7355 23126 ..., 30661  5963 15815]
# iteration 0 / 1000: loss 13.495731
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 1.000000e+05 hidden_size 10.000000
# Permutation:  [28321 29174 20985 ..., 34723 48168   312]
# iteration 0 / 1000: loss 3.119790
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 1.000000e+05 hidden_size 25.000000
# Permutation:  [47383  4982 23912 ..., 14144 33997  2561]
# iteration 0 / 1000: loss 4.404581
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 1.000000e+05 hidden_size 50.000000
# Permutation:  [36871 14967 14436 ..., 20984  1322  7070]
# iteration 0 / 1000: loss 6.500557
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 1.000000e+05 hidden_size 100.000000
# Permutation:  [26094 25168 28090 ...,  2043 17175 22761]
# iteration 0 / 1000: loss 10.593530
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-03 reg 1.000000e+05 hidden_size 200.000000
# Permutation:  [28347 30170 21121 ..., 34709 17334 16699]
# iteration 0 / 1000: loss 18.897950
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-02 reg 1.000000e+04 hidden_size 10.000000
# Permutation:  [36535 45467 24263 ..., 26089 21220   700]
# iteration 0 / 1000: loss 2.386327
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-02 reg 1.000000e+04 hidden_size 25.000000
# Permutation:  [  899 33261  3760 ...,  9279  4790 35257]
# iteration 0 / 1000: loss 2.511111
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-02 reg 1.000000e+04 hidden_size 50.000000
# Permutation:  [14804  9900 43804 ..., 30498 24734 18945]
# iteration 0 / 1000: loss 2.707612
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-02 reg 1.000000e+04 hidden_size 100.000000
# Permutation:  [ 7113 35698 37571 ..., 29320  9743  2556]
# iteration 0 / 1000: loss 3.118756
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-02 reg 1.000000e+04 hidden_size 200.000000
# Permutation:  [20419  6779 32035 ..., 17029 44907   713]
# iteration 0 / 1000: loss 3.940417
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-02 reg 1.467799e+04 hidden_size 10.000000
# Permutation:  [34247 30214 36276 ..., 17449  4412  4165]
# iteration 0 / 1000: loss 2.420670
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-02 reg 1.467799e+04 hidden_size 25.000000
# Permutation:  [ 9187 31095 29763 ..., 29769 19392 16325]
# iteration 0 / 1000: loss 2.601930
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-02 reg 1.467799e+04 hidden_size 50.000000
# Permutation:  [11463  4405 25132 ..., 46906  7591 42367]
# iteration 0 / 1000: loss 2.913621
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-02 reg 1.467799e+04 hidden_size 100.000000
# Permutation:  [23075 31333 27950 ...,    56  7834 17907]
# iteration 0 / 1000: loss 3.520507
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-02 reg 1.467799e+04 hidden_size 200.000000
# Permutation:  [43095 22660 42000 ..., 41655 10586 33090]
# iteration 0 / 1000: loss 4.715571
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-02 reg 2.154435e+04 hidden_size 10.000000
# Permutation:  [ 3434 39462 17920 ..., 41070 42228   905]
# iteration 0 / 1000: loss 2.478426
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-02 reg 2.154435e+04 hidden_size 25.000000
# Permutation:  [ 3025 33355 26035 ..., 13247  8165 14991]
# iteration 0 / 1000: loss 2.734536
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-02 reg 2.154435e+04 hidden_size 50.000000
# Permutation:  [34595 27747 24157 ..., 42090 13766 30073]
# iteration 0 / 1000: loss 3.193328
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-02 reg 2.154435e+04 hidden_size 100.000000
# Permutation:  [14536 45623 42617 ..., 35195  7652  6206]
# iteration 0 / 1000: loss 4.086494
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-02 reg 2.154435e+04 hidden_size 200.000000
# Permutation:  [34650 14814 18998 ..., 31770 22416 19742]
# iteration 0 / 1000: loss 5.869960
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-02 reg 3.162278e+04 hidden_size 10.000000
# Permutation:  [26321 40496 30265 ...,  5717 30195 35849]
# iteration 0 / 1000: loss 2.565106
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-02 reg 3.162278e+04 hidden_size 25.000000
# Permutation:  [  184 41833 21216 ..., 45687 44713 13850]
# iteration 0 / 1000: loss 2.959446
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-02 reg 3.162278e+04 hidden_size 50.000000
# Permutation:  [17924 31199 30641 ..., 16875 14145  9581]
# iteration 0 / 1000: loss 3.601664
# iteration 100 / 1000: loss nan
# iteration 200 / 1000: loss nan
# iteration 300 / 1000: loss nan
# iteration 400 / 1000: loss nan
# iteration 500 / 1000: loss nan
# iteration 600 / 1000: loss nan
# iteration 700 / 1000: loss nan
# iteration 800 / 1000: loss nan
# iteration 900 / 1000: loss nan
# training accuracy: 0.100265
# validation accuracy: 0.087000
# -----------------------------------------
# Start NN lr 1.000000e-02 reg 3.162278e+04 hidden_size 100.000000
# ...
# lr 1.000000e-02 reg 4.641589e+04 hidden_size 25.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-02 reg 4.641589e+04 hidden_size 50.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-02 reg 4.641589e+04 hidden_size 100.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-02 reg 4.641589e+04 hidden_size 200.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-02 reg 6.812921e+04 hidden_size 10.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-02 reg 6.812921e+04 hidden_size 25.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-02 reg 6.812921e+04 hidden_size 50.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-02 reg 6.812921e+04 hidden_size 100.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-02 reg 6.812921e+04 hidden_size 200.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-02 reg 1.000000e+05 hidden_size 10.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-02 reg 1.000000e+05 hidden_size 25.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-02 reg 1.000000e+05 hidden_size 50.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-02 reg 1.000000e+05 hidden_size 100.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-02 reg 1.000000e+05 hidden_size 200.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 1.000000e+04 hidden_size 10.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 1.000000e+04 hidden_size 25.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 1.000000e+04 hidden_size 50.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 1.000000e+04 hidden_size 100.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 1.000000e+04 hidden_size 200.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 1.467799e+04 hidden_size 10.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 1.467799e+04 hidden_size 25.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 1.467799e+04 hidden_size 50.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 1.467799e+04 hidden_size 100.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 1.467799e+04 hidden_size 200.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 2.154435e+04 hidden_size 10.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 2.154435e+04 hidden_size 25.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 2.154435e+04 hidden_size 50.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 2.154435e+04 hidden_size 100.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 2.154435e+04 hidden_size 200.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 3.162278e+04 hidden_size 10.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 3.162278e+04 hidden_size 25.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 3.162278e+04 hidden_size 50.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 3.162278e+04 hidden_size 100.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 3.162278e+04 hidden_size 200.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 4.641589e+04 hidden_size 10.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 4.641589e+04 hidden_size 25.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 4.641589e+04 hidden_size 50.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 4.641589e+04 hidden_size 100.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 4.641589e+04 hidden_size 200.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 6.812921e+04 hidden_size 10.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 6.812921e+04 hidden_size 25.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 6.812921e+04 hidden_size 50.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 6.812921e+04 hidden_size 100.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 6.812921e+04 hidden_size 200.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 1.000000e+05 hidden_size 10.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 1.000000e+05 hidden_size 25.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 1.000000e+05 hidden_size 50.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 1.000000e+05 hidden_size 100.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-01 reg 1.000000e+05 hidden_size 200.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 1.000000e+04 hidden_size 10.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 1.000000e+04 hidden_size 25.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 1.000000e+04 hidden_size 50.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 1.000000e+04 hidden_size 100.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 1.000000e+04 hidden_size 200.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 1.467799e+04 hidden_size 10.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 1.467799e+04 hidden_size 25.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 1.467799e+04 hidden_size 50.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 1.467799e+04 hidden_size 100.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 1.467799e+04 hidden_size 200.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 2.154435e+04 hidden_size 10.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 2.154435e+04 hidden_size 25.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 2.154435e+04 hidden_size 50.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 2.154435e+04 hidden_size 100.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 2.154435e+04 hidden_size 200.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 3.162278e+04 hidden_size 10.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 3.162278e+04 hidden_size 25.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 3.162278e+04 hidden_size 50.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 3.162278e+04 hidden_size 100.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 3.162278e+04 hidden_size 200.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 4.641589e+04 hidden_size 10.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 4.641589e+04 hidden_size 25.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 4.641589e+04 hidden_size 50.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 4.641589e+04 hidden_size 100.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 4.641589e+04 hidden_size 200.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 6.812921e+04 hidden_size 10.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 6.812921e+04 hidden_size 25.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 6.812921e+04 hidden_size 50.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 6.812921e+04 hidden_size 100.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 6.812921e+04 hidden_size 200.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 1.000000e+05 hidden_size 10.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 1.000000e+05 hidden_size 25.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 1.000000e+05 hidden_size 50.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 1.000000e+05 hidden_size 100.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+00 reg 1.000000e+05 hidden_size 200.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 1.000000e+04 hidden_size 10.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 1.000000e+04 hidden_size 25.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 1.000000e+04 hidden_size 50.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 1.000000e+04 hidden_size 100.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 1.000000e+04 hidden_size 200.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 1.467799e+04 hidden_size 10.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 1.467799e+04 hidden_size 25.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 1.467799e+04 hidden_size 50.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 1.467799e+04 hidden_size 100.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 1.467799e+04 hidden_size 200.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 2.154435e+04 hidden_size 10.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 2.154435e+04 hidden_size 25.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 2.154435e+04 hidden_size 50.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 2.154435e+04 hidden_size 100.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 2.154435e+04 hidden_size 200.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 3.162278e+04 hidden_size 10.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 3.162278e+04 hidden_size 25.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 3.162278e+04 hidden_size 50.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 3.162278e+04 hidden_size 100.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 3.162278e+04 hidden_size 200.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 4.641589e+04 hidden_size 10.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 4.641589e+04 hidden_size 25.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 4.641589e+04 hidden_size 50.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 4.641589e+04 hidden_size 100.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 4.641589e+04 hidden_size 200.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 6.812921e+04 hidden_size 10.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 6.812921e+04 hidden_size 25.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 6.812921e+04 hidden_size 50.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 6.812921e+04 hidden_size 100.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 6.812921e+04 hidden_size 200.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 1.000000e+05 hidden_size 10.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 1.000000e+05 hidden_size 25.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 1.000000e+05 hidden_size 50.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 1.000000e+05 hidden_size 100.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+01 reg 1.000000e+05 hidden_size 200.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 1.000000e+04 hidden_size 10.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 1.000000e+04 hidden_size 25.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 1.000000e+04 hidden_size 50.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 1.000000e+04 hidden_size 100.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 1.000000e+04 hidden_size 200.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 1.467799e+04 hidden_size 10.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 1.467799e+04 hidden_size 25.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 1.467799e+04 hidden_size 50.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 1.467799e+04 hidden_size 100.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 1.467799e+04 hidden_size 200.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 2.154435e+04 hidden_size 10.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 2.154435e+04 hidden_size 25.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 2.154435e+04 hidden_size 50.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 2.154435e+04 hidden_size 100.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 2.154435e+04 hidden_size 200.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 3.162278e+04 hidden_size 10.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 3.162278e+04 hidden_size 25.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 3.162278e+04 hidden_size 50.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 3.162278e+04 hidden_size 100.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 3.162278e+04 hidden_size 200.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 4.641589e+04 hidden_size 10.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 4.641589e+04 hidden_size 25.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 4.641589e+04 hidden_size 50.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 4.641589e+04 hidden_size 100.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 4.641589e+04 hidden_size 200.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 6.812921e+04 hidden_size 10.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 6.812921e+04 hidden_size 25.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 6.812921e+04 hidden_size 50.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 6.812921e+04 hidden_size 100.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 6.812921e+04 hidden_size 200.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 1.000000e+05 hidden_size 10.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 1.000000e+05 hidden_size 25.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 1.000000e+05 hidden_size 50.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 1.000000e+05 hidden_size 100.000000 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e+02 reg 1.000000e+05 hidden_size 200.000000 train accuracy: 0.100265 val accuracy: 0.087000
# best validation accuracy achieved during cross-validation: 0.119000

# %%
# Run your neural net classifier on the test set. You should be able to
# get more than 55% accuracy.

test_acc = (net.predict(X_test_feats) == y_test).mean()
print test_acc
# Out:
# 0.1

# %% [markdown]
# # Bonus: Design your own features!
#
# You have seen that simple image features can improve classification performance. So far we have tried HOG and color histograms, but other types of features may be able to achieve even better classification performance.
#
# For bonus points, design and implement a new type of feature and use it for image classification on CIFAR-10. Explain how your feature works and why you expect it to be useful for image classification. Implement it in this notebook, cross-validate any hyperparameters, and compare its performance to the HOG + Color histogram baseline.

# %% [markdown]
# # Bonus: Do something extra!
# Use the material and code we have presented in this assignment to do something interesting. Was there another question we should have asked? Did any cool ideas pop into your head as you were working on the assignment? This is your chance to show off!
